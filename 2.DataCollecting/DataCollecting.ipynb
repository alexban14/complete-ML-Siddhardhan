# %% [markdown]
# # Datasets collection sites
# > 1. Kaggle
# > 2. UCI ML Repository
# > 3. Google Dataset Search

# %%
import pandas as pd

# %%
# loading dataset into pandas DataFrame
dataset = pd.read_csv('boston.csv')

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# # Loading Datasets from Kaggle API
#
# * Kaggle API dataset import
# * Kaggle pip library must be installed
# * Kaggle API token (kaggle.json file) must be added to the path C:\Users\{username}\.kaggle directory
# * Python Scripts folder must be added to Path Variables

# %%
# fetching dataset from kaggle using cmd
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
#   0%|          | 0.00/2.27G [00:00<?, ?B/s]
#   0%|          | 1.00M/2.27G [00:00<29:17, 1.39MB/s]
#   0%|          | 2.00M/2.27G [00:01<20:05, 2.02MB/s]
#   0%|          | 3.00M/2.27G [00:01<20:06, 2.02MB/s]
#   0%|          | 4.00M/2.27G [00:01<15:59, 2.54MB/s]
#   0%|          | 5.00M/2.27G [00:02<14:51, 2.73MB/s]
#   0%|          | 6.00M/2.27G [00:02<13:59, 2.90MB/s]
#   0%|          | 7.00M/2.27G [00:02<13:13, 3.07MB/s]
#   0%|          | 8.00M/2.27G [00:03<12:23, 3.27MB/s]
#   0%|          | 9.00M/2.27G [00:03<12:25, 3.26MB/s]
#   0%|          | 10.0M/2.27G [00:03<12:32, 3.23MB/s]
#   0%|          | 11.0M/2.27G [00:03<11:26, 3.54MB/s]
#   1%|          | 12.0M/2.27G [00:04<11:17, 3.59MB/s]
#   1%|          | 13.0M/2.27G [00:04<10:59, 3.68MB/s]
#   1%|          | 14.0M/2.27G [00:04<12:58, 3.12MB/s]
#   1%|          | 15.0M/2.27G [00:05<14:54, 2.71MB/s]
#   1%|          | 16.0M/2.27G [00:05<14:58, 2.70MB/s]
#   1%|          | 17.0M/2.27G [00:06<12:31, 3.22MB/s]
# ...

# %%
# extracting the compressed Dataset
from zipfile import ZipFile
zipDataset = 'LANL-Earthquake-Prediction.zip'

with ZipFile(zipDataset, 'r') as zip:
    zip.extractall()
    print('Dataset extracted!')
# Out:
# Dataset extracted!
